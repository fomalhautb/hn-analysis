# %%
import pandas as pd
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import mean_squared_error
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import sklearn
import math

# Ensure the following NLTK data is downloaded
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
nltk.download('stopwords', quiet=True)
# Out:
# True

# %%
df = pd.read_csv('data.csv')
df = df[df['title'].str.contains('Show HN', na=False)]

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_and_lemmatize(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize
    tokens = word_tokenize(text)
    # Remove stop words and lemmatize
    lemmatized = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(lemmatized)

df['processed_title'] = df['title'].apply(preprocess_and_lemmatize)

# %%
def transform_score(score):
    transformed_score = math.log(max(score, 1))
    max_val = math.log(df['score'].max())
    return transformed_score / max_val * 2 - 0.5

def untransform_score(transformed_score):
    max_val = math.log(df['score'].max())
    transformed_score = (transformed_score + 0.5) * max_val / 2
    return math.exp(transformed_score)

df['transformed_score'] = df['score'].apply(transform_score)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['processed_title'])
y = df['transformed_score']
X_train, X_test, y_train, y_test, _, title_test, _, score_test = train_test_split(X, y, df['title'], df['score'], test_size=0.2, random_state=42)

# %%
model = sklearn.linear_model.SGDRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

correct_count = 0
for y_pred_val, score in zip(y_pred, score_test):
    y_pred_score = untransform_score(y_pred_val)
    if score < 10:
        correct_count += int(y_pred_score < 10)
    elif score < 50:
        correct_count += int(10 <= y_pred_score < 50)
    elif score < 100:
        correct_count += int(50 <= y_pred_score < 100)
    else:
        correct_count += int(100 <= y_pred_score)

accuracy = correct_count / len(y_pred)
print(f"Accuracy: {accuracy}")

print('Accuracy of always predicting 0-10:', len(score_test[score_test < 10]) / len(score_test))
# Out:
# Mean Squared Error: 0.11055383797847552
# Accuracy: 0.7951248066229042
# Accuracy of always predicting 0-10: 0.7957519755822219

# %%
def predict(title):
    processed_title = preprocess_and_lemmatize(title)
    X = vectorizer.transform([processed_title])
    return model.predict(X)[0]

for title, gt_score in zip(title_test, score_test):
    score = untransform_score(predict(title))
    if score > 10 or gt_score > 10:
        print(f"{title} | {round(score)}", gt_score)
# Out:
# Show HN: Simpler access to your music from the web that looks nice | 5 86
# Show HN: ARRIVE SDK – Know When Customers Are Arriving | 3 17
# Show HN: Reactpack – one command to build your React front end | 5 108
# Show HN: Classes for javascript that you'd actually use | 4 52
# Show HN: Aura – Machine Learning-driven mindfulness program | 4 16
# Show HN: CattlePi automated setup and updates for Raspberry Pi(s) | 4 60
# Show HN: A Raspberry Pi Video Streaming Robot | 5 19
# Show HN: I made an app for creating fancy app store screenshots | 4 17
# Show HN: A map that shows you how far you can go for a given time or distance | 2 455
# Show HN: Security Book Reviews - My side project for hackers and makers | 7 25
# Show HN: Unicaps - a Python package for CAPTCHA solving | 4 17
# Show HN: roundabout.io - Jobs for devs by devs (London) | 4 14
# Show HN: Formie – an open source (WIP) form website made with pure HTML/JS/CSS | 7 17
# Show HN: YC like button | 5 21
# Show HN: Howm – A Vim-like tiling X11 window manager | 4 71
# Show HN: FalsiScan – Make it look like a PDF has been hand signed and scanned | 5 770
# Show HN: Dat-keyserver: a distributed PGP keyserver based on the Dat protocol | 4 106
# Show HN: Londoners need not worry about the waiting time paradox | 3 12
# Show HN: vi in your browser - edit files directly from Dropbox, etc | 5 206
# Show HN: CIS Force – we match tech companies with reliable vetted freelancers | 3 31
# Show HN: Hacker News with tweets from your friends (yc.backtype.com) | 4 44
# Show HN: NYTimesArchive – Python Wrapper for the New York Times Archive API | 4 13
# Show HN: Tramline – release cycle coordination platform just for mobile apps | 4 13
# Show HN: Proxy Orbit – Rotating Web Proxy API for Pentesting | 5 12
# Show HN: Central Dogma – highly-available version-controlled config repository | 4 12
# Show HN: Never lose a website again | 4 78
# Our Show HN post results, 1 week later | 3 31
# Show HN: RequestHub – route webhooks from one service to others | 4 15
# Show HN: Free site to learn and try different databases | 6 26
# Show HN: Photo Picker+, New Library Improves Native Photo Picker (iOS+Android) | 5 121
# Show HN: Online CV/Resume Maker in React Using Facebook's Draft-Js | 4 22
# Show HN: A search engine based on RSS feed | 4 134
# Show HN: Themefinder – Interactively find wordpress themes | 3 18
# Show HN: Seashells – Pipe output from CLI apps to the web in real time | 5 356
# Show HN: Color Picker for iOS and Android developers | 3 38
# Show HN: Clio Programming Language | 7 14
# Show HN: three-geo – Geographic visualization with three.js | 4 41
# Show HN: We made a site to crowd fund lobbying. | 5 50
# Show HN: Drop-In Chat – Chatify your app | 4 49
# Show HN: Dextro Stream – Periscope livestream discovery with computer vision | 4 43
# Show HN: round.io, our side project for the last two years | 6 38
# Show HN: Decentralized Graph Database for Node.js and Browsers | 7 14
# Show HN: Tool to Convert a YouTube Channel to an Alexa Skill | 3 12
# Show HN: I made a movie recommendation app based on your mood | 4 163
# Show HN: Obey JavaScript Data Validation and Modeling | 4 13
# Show HN: Free Hosted JupyerLab with GPU | 5 12
# Show HN: Export Mail for Microsoft Outlook for Mac | 4 46
# Show HN: pgcmd – An alternative to psql with JSON output | 6 76
# Show HN: Gitern is a Git host for hackers | 6 112
# Show HN: Krypton – make your phone a U2F Authenticator | 4 12
# Show HN: Spread bitcoins by lending to friends | 4 67
# Show HN: TCP/UDP over sound | 4 186
# Show HN: PolyBrowser 2.0 – Linux/Firebug/LastPass compatible. What do you think? | 4 13
# Show HN: Use Ansible to Run a “friends and Family” OpenVPN Server on Digital Ocean | 4 206
# Show HN: Record and share police/fire radio systems | 4 102
# Show HN: PodCastle - Reddit for podcasts | 4 40
# Show HN: Leet Resumes – a free technical resume-writing service | 4 147
# Show HN: I made a site that lets you easily find live-coding streams | 6 11
# Show HN: I made a solar-powered, ePaper photo frame | 6 27
# Show HN: Use Google Spreadsheet as a Database | 6 34
# Show HN: RowStack – Streamline your team task management | 3 30
# Show HN: FreshJobs – An aggregator of junior and entry-level jobs | 4 106
# Show HN: I got a list of 2000 Venture Capitalist Firms | 4 20
# Show HN: B2blaze – A Backblaze B2 library for Python | 4 359
# Show HN: Ranking Your University Using PageRank on Wikipedia | 4 13
# Show HN: Buttercoin (YC S13) US Bitcoin Marketplace – Free Trading Through Dec | 5 69
# Show HN: Galga – I made a digital card game | 4 15
# Show HN: A thread hierarchy management library in C | 3 53
# Show HN: pan.do/ra - a free, open source platform for video archives | 5 20
# Show HN: Made my own date picker for AngularJS | 4 44
# Show HN: Online web tools to get your work done faster | 6 118
# Show HN: BillBuddy – Automated Invoice Processing | 5 39
# Show HN: Initial release of H2O, and why HTTPD performance will matter in 2015 | 3 251
# Show HN: iq – jq for images (using rust, LALRPOP) | 5 13
# Show HN: Nerd Crawler – monitoring original comic art sites so you don't have to | 4 45
# Show HN: MongoDB analytics to track changes in your site's performance | 3 46
# Show HN: I spent a year building a desktop environment that runs in the browser | 11 17
# Show HN: From Excel-hell to cloud database heaven in 5 steps | 5 26
# Show HN: Calculate the layout to hang up pictures on the wall with Python | 4 31
# Show HN: Prevent your free Heroku app from ever falling asleep again | 4 12
# Show HN: Visual Search using HNSearch API | 5 11
# Show HN: Share many links? We made it better with highlights | 4 26
# Show HN: Test Drive The RubyMotion Console From Your Browser | 4 84
# Show HN: Semantic search engine for Lenny's Podcast | 4 14
# Show HN: gleeBox, keyboard glee for your web | 5 39
# Show HN: Earthquakes on Leaflet, Crossfilter and D3 | 4 22
# Show HN: Polygon.io – Real-time Stock APIs, Forex and Crypto | 4 12
# Show HN: LAN Party VPN – Run a VPN on Top of Discord | 4 22
# Show HN: Elevator party – An interactive small talk experience | 4 76
# Show HN: A tool to make a bot that speaks like you, learning from WhatsApp chats | 5 134
# Show HN: Open-Source Shopify (Medusa) | 7 14
# Show HN: Wayland Explorer – Easily read Wayland protocol documentation online | 4 44
# Show HN: Automatic VPN Generator – Protect Yourself at Sochi and Starbucks | 4 125
# Show HN: XMD – An Extensible Markdown Format | 5 13
# Show HN: SinglePage – Quickly and anonymously publish a page to the web | 5 175
# Show HN: E-graphs and equality saturation in Haskell | 4 22
# Show HN: Loofi – Our AI-Powered SQL Query Builder | 5 19
# Show HN: Four years of profitable side-projects | 5 145
# Show HN: Marketing image generation tools and API | 3 24
# Show HN: Feedster, a semi-minimalistic open-source selfhosted RSS Reader | 12 11
# Show HN: Hearth – A Dropbox-like, IPFS-powered personal website publisher | 5 315
# Show HN: Archivy – Self-hosted knowledge base embedded into your filesystem | 6 219
# Show HN: Boat – Big O analysis tool | 3 24
# Show HN: Git-fired tells you who was fired / added based on Git log | 4 40
# Show HN: Instant Answers – Have 1:1 conversations with any given text source | 4 15
# Show HN: Schema-DTS, TypeScript Shims for Schema.org and the Semantic Web | 4 27
# Show HN: Dassana. JSON-native,schema-less logging solution built atop ClickHouse | 5 25
# Show HN: Get Domain Like Ninja – Domain from Keywords, Synonyms | 4 13
# Show HN: I built this game alone – design, code, music, sound, marketing | 5 214
# Show HN: Network of celebrity ice bucket challenges, visualized | 4 29
# Show HN: The Xing Framework, Rails API and Angular, Simplified | 4 28
# Show HN: Custom New Tab page for Firefox | 3 73
# Show HN: Findsimilar.info - my weekend project | 5 15
# Show HN: RustyBox – a Busybox fork written in Rust | 5 114
# Show HN: Salty, a minimalist DevOps tool inspired by Saltstack and Ansible | 4 32
# Show HN: Suto – Expert advice on products via SMS | 3 11
# Show HN: Solo, open source FIDO2 security key | 5 98
# Show HN: Jumpstarter – Turn your WordPress themes into hosted web apps | 6 13
# Show HN: Our alternative to recruiter spam | 6 233
# Show HN: Jazzroom, collaborative real-time music hack in Node.js | 5 45
# Show HN: Remove backgrounds from images online | 4 571
# Show HN: Evaluate your startup ideas in 30 seconds – Shouldimakeit.com | 4 18
# Show HN: A small text editor in go inspired by kilo editor | 10 3
# Show HN: CC/Fwd any email with a URL to get an email of extracted main text | 5 14
# Show HN: FileRock, a Secure Dropbox Clone, goes Open Source | 6 97
# Show HN: Windsor – See All Your Users' Events | 3 17
# Show HN: Spin-docker – a lightweight RESTful docker PaaS | 4 14
# Show HN: Bookmark Knocking – Hidden Bookmarks Without a Browser Extension | 5 50
# Show HN: Add sticky notes to your GitHub issues with a collaborative whiteboard | 5 13
# Show HN: Gomp – a tool for comparing Git branches | 4 92
# Show HN: Pinnin – A simple Pinboard client for iPhone | 3 15
# Show HN: Spotify streaming GDPR dump local analyzer | 4 104
# Show HN: Learn Web Development for Free with The Odin Project | 6 63
# Show HN: GPT-4 autonomously editing a program allowing it to edit programs | 4 52
# Show HN: Prioritize next launch feature set with anonymous input from your team | 3 13
# Show HN: Walk around unusual geometries | 4 149
# Show HN: TrueUX prototype, text command wireframing | 4 11
# Show HN: Spanish election results – D3 newsapp | 3 62
# Show HN: Open-Source Stripe GraphQL API | 10 41
# Show HN: C++/.Net SDK for different natural language processing tasks | 5 12
# Show HN: Weekly – a simple and fast todo list for every device | 5 19
# Show HN: Open Web API – Access any website without getting blocked | 7 14
# Show HN: Keep your customers informed and aware | 3 12
# Show HN: No Signup, Yet, Authenticated Posts | 3 44
# Show HN: Snips is a AI Voice Assistant platform 100% on-device and private | 4 372
# Show HN: An experimental, people-powered search engine | 5 215
# Show HN: Page00 – Publishing content anonymously | 3 11
# Show HN: Selenium-like user flow testing, but with a nicer interface | 4 25
# Show HN: Z shell configuration, zsh startup files, when they load, what they do | 5 85
# Show HN: Emacs Anywhere – Use Emacs Anywhere | 4 11
# Show HN: Startup Map of Israel - My weekend project | 5 12
# Show HN: Omniflow – Structure for your thoughts | 4 27
# Show HN: Wave-share – serverless, peer-to-peer, local file sharing through sound | 5 49
# Show HN: Ng-dial – An Angular.js directive for an interactive dial component | 4 25
# Show HN: I created a Chrome extension to help keep good posture while browsing | 3 13
# Show HN: TheBigDB - A simpler open database of facts | 5 133
# Show HN: Snips open-sources its embedded NLU, to build private-by-design AI | 4 11
# Show HN: GoInstant widgets - building blocks for multi-user apps | 5 19
# Show HN: Fork, a toy self-hosting language and compiler that compiles to C | 6 58
# Show HN: Meteor Platform Roadmap, in social upvoting format, built with Meteor | 4 11
# Show HN: Handwritten.js – Convert typed text to realistic handwriting | 6 255
# Show HN: Draw your time series with the Time Series Maker | 4 17
# Show HN: A friend and I spent 6 years making a simulation game, finally released | 5 1157
# Show HN: My collection of web-apps that I'm finally comfortable in sharing | 5 238
# Show HN: Paths.js – Generate SVG paths for geometric shapes | 4 86
# Show HN: JavaScript non-blocking cartograms | 4 13
# Show HN: Practicing Rails: Learn Rails without being overwhelmed | 4 11
# Show HN: Control your Hyundai car with Python | 5 98
# Show HN: Off-grid web server for the developing world | 5 47
# Show HN: Sioyek – PDF viewer for reading research papers and technical documents | 5 272
# Show HN: Zube.io – Simple project management for your GitHub issues | 4 66
# Show HN: Bootstrapping an asset store for AR creators and ML engineers | 4 21
# Show HN: Rails-Inspired PHP Framework | 4 28
# Show HN: Socket.js, a tiny WebSockets library for Node.js | 4 11
# Show HN: Maze Generation Visualization | 4 70
# Show HN: Coinwell - the easiest way to mine litecoins | 4 13
# Show HN: A neural net that critiques your logo | 5 152
# Show HN: Does Facebook know your friends better than you do? | 3 34
# Show HN: Fr8, an Open-Source Cloud Application Integration Service (iPaaS) | 6 15
# Show HN: HN Special – A visual theme and Chrome extension for Hacker News | 6 87
# Show HN: MasterWP – become a WordPress power user, fast | 4 13
# Show HN: Skiplit - an iOS puzzle game where simple & impossible are synonyms | 3 11
# Show HN: Pg_CRDT – an experimental CRDT extension for Postgres | 4 296
# Show HN: Zmsg – Zero knowledge messaging system built on zcash | 6 18
# Show HN: A dependently-typed programming language with static memory management | 7 456
# Show HN: A freelance-only job board | 4 26
# Show HN: Personalized email addresses for your entire family | 4 34
# Show HN: Small project on particle animation, genetic algorithms and plain JS | 6 15
# Show HN: Hello, a CLI tool for managing social media | 2 24
# Show HN: Life – A secure, blazing-fast, cross-platform WebAssembly VM in Go | 6 111
# Show HN: Coding WebIDE goes open source – The WebIDE Community Edition | 5 13
# Show HN: Pdf.to – PDF Editor, PDF to Word, PDF Combiner | 6 40
# Show HN: $1 buys you a startup idea | 4 11
# Show HN: my new project, an anti-snub dating site | 5 119
# Show HN: Bender – a Deep Learning framework for iOS | 5 81
# Show HN: Coding Tips Every Monday | 4 15
# Show HN: The Least Dangerous To-Do List | 4 141
# Show HN: Identifying, Segmenting and Contacting our Customers | 4 11
# Show HN: Parsing horse racing charts with Apache PDFBox | 4 115
# Show HN: Veneer, modal dialogs in 75 lines of JavaScript | 4 56
# Show HN: Real-time Team Collaboration on top of your LinkedIn Social Graph | 4 14
# Show HN: Csysdig – think strace and htop and Lua and container support | 4 19
# Show HN: I made an app for designing Embedded Systems and code generation | 5 25
# Show HN: Lambdaway | 4 29
# Show HN: The powerful software development tool designed to eliminate boundaries | 4 13
# Show HN: Minimalist Google Play Music Wrapper – Electron | 4 16
# Show HN:  VerticalChange, SurveyMonkey meets Highrise (and a LOT of AngularJS) | 4 16
# Show HN: Find PCB Footprints and Schematic Symbols Within EAGLE | 4 12
# Show HN: Timeslot makes planning your day a breeze | 4 71
# Show HN: Ultra, a Leiningen plugin for a superior development environment | 3 144
# Show HN: TLD.ninja – Simple top-level domain checker (weekend project) | 5 15
# Show HN: Triangulart – Isometric graphic editor, like pixel art with triangles | 8 95
# Show HN: Brainstorm Troubles | 4 20
# Show HN: Hacker News Lookup - A chrome extension built with ClojureScript | 6 17
# Show HN: Debugging Babel and Node done right | 4 22
# Show HN: Anonymous interview evals of strong software/ML engineering candidates | 4 95
# Show HN: Quiver – GraphQL on Steroids | 5 54
# Show HN: Hacker News reader focused on readability | 6 19
# Show HN: Hide Secret Messages In Facebook Photos With My Chrome Extension | 3 153
# Show HN: A sokoban clone game with "infinity" levels | 4 13
# Show HN: JavaScript and Node.js API (Library) for Dropbox, Google, OneDrive and Box | 4 11
# Show HN: Started.in Seattle – 60+ Video Profiles of startups in Seattle | 3 58
# Show HN: Bootstrapped, Not Profitable *Yet*, & Proud: Pagify | 4 44
# Show HN: Postman – A command-line utility for batch-sending email | 4 48
# Show HN: Internet Fight Club | 4 32
# Show HN: Write a private diary using good old email | 5 515
# Show HN: Discover, Listen and Discuss Classical Music | 4 273
# Show HN: CAD model of the saturn V rocket on the 55th anniversary of Apollo 8 | 4 20
# Show HN: QDB, a remote python debugger | 4 31
# Show HN: We're helping kids access capital | 4 27
# Show HN: A gong that rings automatically when we get a new client | 3 11
# Show HN: Simple Piano Note Detector | 4 14
# Show HN: Check if my startup ideas have legs | 4 22
# Show HN: Code Notes – A Gatsby theme for publishing code-related notes | 5 151
# Show HN: Inside – The network of email newsletters | 4 42
# Show HN: I wrote a free Mac app to OCR any text on screen | 6 321
# Show HN: Uffizzi – Open-Source Preview Environments | 8 13
# Show HN: Create a Marketing Site for your Startup in Minutes | 4 30
# Show HN: TextMyWeight – Keep track of your weight over time (Twilio App) | 2 11
# Show HN: RapGenii – Contribute to crowdsourced rap lyrics | 3 13
# Show HN: Never forget what you've learned | 4 12
# Show HN: Rails One Click Installer for Mac Os X | 4 92
# Show HN: Low rated but popular Chrome extensions | 3 19
# Show HN: You had a productive day, until now | 4 133
# Show HN: Integer Factors Wrapped on a Sphere | 4 19
# Show HN: Grip – Analyzing our own software development with machine learning | 4 15
# Show HN: DocAsker – Use LLMs to ask documentation questions | 4 97
# Show HN: Lapce – open-source code editor inspired by Xi-editor | 11 7
# Show HN: Mountain Growl - Growl plugin for Mountain Lions Notification Center | 2 44
# Show HN: Decentralized, k-ordered unique IDs in Clojure | 5 53
# Show HN: Purview – A server-side component framework | 4 58
# Show HN: A list of no-code software, by category, with real-world examples | 4 75
# Show HN: MAME-PSGS – A MAME's GLSL Shader capable of color palette customization | 4 19
# Show HN: my boilerplate CSS code for new designs, written in Less. | 5 108
# Show HN: I built a reverse image search for pixel art | 6 129
# Show HN: Rudolph Runner | 4 61
# Show HN: JavascriptU, workshops on modern JavaScript patterns & libraries | 5 14
# Show HN: Load this image from a peer rather than from a web server (open source) | 7 65
# Show HN: Pidove, an Alternative to the Java Streams API | 5 28
# Show HN: Prolog compiler and interpreter in pure JavaScript | 7 15
# Show HN: ReactCasts, a series of short videos explaining React's APIs and concepts | 3 20
# Show HN: anonymous, ephemeral picture-sharing site built at Rackspace's HackDay | 6 28
# Show HN: Manage access to Basecamp, GitHub, Heroku, and more | 4 35
# Show HN: A Dashboard for External Monitors | 4 68
# Show HN: Encore – Go backend framework with superpowers | 5 11
# Show HN: Chaos Llama – Chaos Monkey Build on AWS Lambda | 5 12
# Show HN: Simplest chat for platforms and marketplaces | 4 47
# Show HN: Mobile App Automizer | 3 22
# Show HN: Appbase – Data synchronization library for writing 100% clientside apps | 6 19
# Show HN: Inline SQL in any Python program | 6 26
# Show HN: CuriosityStream – Netflix for non-fiction | 4 129
# Show HN: SQLSite – serve simple websites, APIs and files directly from SQLite | 6 52
# Show HN: TextWallpaper.Online – Create plain text solid background wallpapers | 5 12
# Show HN: Recursive PNG Generator | 4 12
# Show HN: jQuery.pin – a plugin for making stuff stick | 3 65
# Show HN: A Simple Online Step Sequencer | 4 60
# Show HN: Practice Python Projects eBook for beginners | 5 27
# Show HN: Socratease – A Joyful Way To Learn Things | 5 27
# Show HN: Breeeathe.com | 4 15
# Show HN: The Road to learn React – Build a Hacker News App on the Way | 7 339
# Show HN: OOTB Code-Server, Easiest “VSCode on Browser” + HTTPS and GitHub Auth | 5 11
# Show HN: Morfa – new programming language – general purpose and DSL-friendly | 6 32
# Show HN: Off-premises insight for on-premises Prometheus servers | 4 53
# Show HN: ElasticUI – AngularJS Directives for ElasticSearch | 4 39
# Show HN: Create your own personalized web search index | 4 12
# Show HN: Sauron – A live news visualization map | 5 11
# Show HN: New site that predicts when an airfare will go up or down | 5 13
# Show HN: Urubu – A micro CMS for static websites | 5 80
# Show HN: SwiftGPT – The native macOS app for ChatGPT | 4 27
# Show HN: Payback, a web app to make spending and borrowing money easier | 4 15
# Show HN: Chat with people around you | 4 38
# Show HN: VeryAnts: Probabilistic Integer Arithmetic for Ruby | 4 45
# Show HN: Breathe – Peripheral Breath Trainer | 4 167
# Show HN: Tinkersynth 2.0 (now with color and open-sourced) | 4 52
# Show HN: I decided to re-create a mini Google Wave | 4 18
# Show HN: RetroClip – Instant Replay for Your Mac | 5 309
# Show HN: I am not a dev, but published a Chrome extension: Cowboy Copy | 3 12
# Show HN: DJS - Media Distribution with no server-side code | 4 31
# Show HN: Interactive implementation of the NIST Blockchain use case flow chart | 4 82
# Show HN: Electron Webpack Dashboard | 4 28
# Show HN: The cheapest investment platforms in the UK | 3 13
# Show HN: Open Source TV Show Airtime Guide | 2 16
# Show HN: A simpler, open-source, different kind of forum/message board | 7 11
# Show HN: HackerNews web push for stories with 100+ upvotes by Roost (YC S14) | 5 32
# Show HN: Automatic Slack reminders for pull requests | 3 22
# Show HN: Hosted JavaScript dependency tree graphs for GitHub READMEs | 5 56
# Show HN: Stream for Desktop: Random Stuff People Anonymously Share on the Web | 4 18
# Show HN: An HTML5 game we made in 72 hours for Ludum Dare | 6 49
# Show HN: DMach – Drum Machine for Android with Pure Data Sound Synthesis | 4 11
# Show HN: I made a site that calculates the market price of items on ebay | 5 87
# Show HN: SpeakingJpg – Hide encrypted text messages inside jpeg images | 5 34
# Show HN: Social experiment with live textboxes | 3 29
# Show HN: A new spline | 4 341
# Show HN: Conway's Game of Life on GitHub contribution board | 4 14
# Show HN: DropCSS – A simple, thorough and fast unused-CSS cleaner | 5 134
# Show HN: Forte, an open-source self-hosted music platform, is now federated | 11 1
# Show HN: Just Get Me Food | 4 58
# Show HN: Review my iPad app: Inspiring Business Quotes | 2 16
# Show HN: Eg – examples at the command line | 3 17
# Show HN: Fluid iPad App Concept  | 3 179
# Show HN: Reveal – an iOS runtime inspection tool | 3 113
# Show HN: I’m not a data scientist but made a Covid mask detector – Doctor Masky | 5 32
# Show HN: Avo – Build Ruby on Rails apps faster | 5 306
# Show HN: CSS3 icons and glyphs that you can use for free | 4 12
# Show HN: Jobs in Tech | 3 12
# Show HN: Prisoner's dilemma tournament with bots that can simulate each other | 3 51
# Show HN: Moon – a tiny UI library inspired by Vue | 6 11
# Show HN: Low-Code Internal Chrome Extension Builder (Developer Preview) | 4 36
# Show HN: What every browser knows about you | 5 553
# Show HN: A Go Library for Website Log Analysis | 4 56
# Show HN: Deep learning visual search and data analytics | 7 74
# Show HN: Ridiculously over-engineered my blog | 3 15
# Show HN: Rmt an alternative to rm with trash written in Rust | 9 45
# Show HN: What are the best features you want to find in uptime monitoring? | 3 14
# Show HN: I built a tool to remove unwanted elements from photos | 6 41
# Show HN: Valhalla, an open source routing engine | 6 147
# Show HN: 6 Months in, first iPhone app into app store today | 3 33
# Show HN: Beautiful and Ridiculously Fast Websites With Static Blogging | 8 28
# Show HN: Nodebook – Minimalist Multi-Language REPL with Web UI | 6 12
# Show HN: Designing Web Applications | 5 105
# Show HN: Comment on GitHub Projects | 5 19
# Show HN: Twincl Editor – A WYSIWYG/Markdown dual-mode editor | 7 55
# Show HN: Website for my high school wood shop class to learn parts on machines | 5 20
# Show HN: ProAnd.Contra, Fast and easy online Pro/Contra opinion polls | 4 24
# Show HN: Domain Name Search with AI | 4 313
# Show HN: Chemozart – molecule editor and visualizer with mechanics calculators | 6 34
# Show HN: Legacy Mac Proxy | 4 14
# Show HN: Gutenberg – Modern CSS framework to print the web correctly | 8 305
# Show HN: Graphsignal – ML profiler to speed up training and inference | 4 16
# Show HN: Randomised email addresses for privacy protection | 4 13
# Show HN: The Year-Long Open-Source Sabbatical | 7 30
# Show HN: Droners.io – Get anything filmed by a drone | 4 65
# Show HN: I've built self-opening trash bin, I relax myself feeding garbage to it | 6 119
# Show HN: Appwrite Cloud Beta | 3 11
# Show HN: better software deployment with Git | 5 66
# Show HN: Domain Wheel – Domain and company name generator | 5 23
# Show HN: Data on Shopify Stores | 4 51
# Show HN: Serverless doc writing app built using Cloudflare Workers and KV Store | 5 69
# Show HN: Hello distributed language user guide [pdf] | 7 18
# Show HN: Embed your AngelList Profile anywhere | 4 14
# Show HN: If Correlation doesn't imply causation, then, what does? | 4 15
# Show HN: 1 kB JavaScript framework for building front end applications | 7 12
# Show HN: myStorify.com - storify your photos | 4 24
# Show HN: Transactional Outbox Pattern in Go | 4 12
# Show HN: I'm 20, a Student, and I created a new type of fantasy sports app | 4 27
# Show HN: Coolify v2 – Open-source and self-hostable Heroku/Netlify alternative | 13 158
# Show HN: Simple, fast and fun communication over Websockets | 4 17
# Show HN: Feed of current articles for science lovers shortened to bullet points | 3 94
# Show HN: drag-drop file uploading for the whole web (Firefox/Chrome) | 5 66
# Show HN: Free Push Infrastructure for RSS Reader | 5 44
# Show HN: An alternative RSS reader and search engine for news and content | 8 86
# Show HN: Tag Along (my first iPhone app 37 days later) | 3 30
# Show HN: Firefox extension to obfuscate web page text | 4 235
# Show HN: S&P 500 Annualized Returns Fun Facts | 4 22
# Show HN: Pixelfed.club – Aggregator for Pixelfed Posts | 3 59
# Show HN: Spy Codes: free booklet for kids (2018) | 5 75
# Show HN: HardyPress – Use WordPress as a static site generator | 4 86
# Show HN: Beautiful Real-Time Polling On Twitter With Analytics | 4 65
# Show HN: A Really Simple Blog Platform | 3 19
# Show HN: I Made an iMessaging API | 5 15
# Show HN: Roomd, find new friends to live with | 4 20
# Show HN: Handicareers.com – A simple job board for disabled people | 4 303
# Show HN: Hbizzle, HBO GO made easy | 5 18
# Show HN: The Organizer for Freelancers and Creatives | 4 17
# Show HN: Pgcli – A CLI for Postgres with auto-completion and syntax highlighting | 5 227
# Show HN: Copytesting Improve your website copy based on data from your audience | 4 13
# Show HN: My multiplayer custom-engine game that loads in less than a second | 4 198
# Show HN: Voice - An iOS App that lets blind people read | 3 57
# Show HN: React UI Component Library | 4 11
# Show HN: BestChoice – Phone-chooser that even your grandma can use | 4 16
# Show HN: Randomly Guessing Bitcoin Addresses | 4 37
# Show HN: Archipelago, a Generative Art Explorer | 4 14
# Show HN: TwoSides.co, because there's at least two sides to every story | 4 23
# Show HN: Scrape the web by injecting JavaScript into web pages | 6 109
# Show HN: Bootstrapper's Handbook building startups the indie way | 6 15
# Show HN: hackernews_tui – A Terminal UI to browse Hacker News discussions | 10 160
# Show HN: ThoughtCoach: Helping to improve mental health with AI | 3 18
# Show HN: VentScape – Minimalistic site to vent, chat and see others do the same | 5 102
# Show HN: I created a JavaScript debugger for iPhone and Android | 3 21
# Show HN: Hurl – Run and test HTTP requests | 4 32
# Show HN: Easy-to-configure Web Server in Go  | 6 106
# Show HN: Golang DNS server, including DNSSEC and DNS-over-TLS | 4 283
# Show HN: We created a hexagonal keyboard made for smartphones | 6 35
# Show HN: Lychee — Self-hosted photo-management done right | 6 92
# Show HN: `curl parrot.live` | 4 35
# Show HN: Hipmob is Olark for mobile apps. (Live support chat, now on Android) | 3 51
# Show HN: Compiler using Lisp’s macro system for metaprogramming C-like languages | 8 80
# Show HN: A low-code alternative for Stripe/Twilio Integrations | 6 34
# Show HN: The easiest way to deploy TensorFlow – Inferrd v2.0 | 5 15
# Show HN: LeapFM - A new way to find music | 4 17
# Show HN: Sqliteweb – Web-Based SQLite database browser (written in Go) | 11 7
# Show HN: Awesome Ideation Tools | 4 26
# Show HN: Hosting for LangChain APIs | 4 12
# Show HN: Jobder – Find the job match your open source contribution | 5 24
# Show HN: Visa-CLI | 4 11
# Show HN: Create-react-extension for browser extensions | 4 14
# Show HN: nunjucks, a better templating system for javascript (jinja2 inspired) | 5 38
# Show HN: A generator of Fake Italian Coffee names | 4 80
# Show HN: Fastn, a JavaScript tool for building user interfaces | 5 47
# Show HN: Baastronaut – open-source Airtable alternative built on PostgREST | 17 5
# Show HN: Parex – Simple Elixir module for parallel execution | 3 43
# Show HN: WebKit Fork that aims to remove all Privacy compromising APIs | 4 12
# Show HN: Habit List - my first iOS app | 3 282
# Show HN: Launched my first app where people hum songs for others to guess | 4 198
# Show HN: Beeple Generator | 4 11
# Show HN: An attempt to spot Covid-19 outbreaks using wearable devices | 4 40
# Show HN: CleverDeck – I built the spaced repetition app I always wanted | 5 305
# Show HN: ExDOS 64-bit version source code release | 3 39
# Show HN: remote access to your Android phone with Shynk | 3 14
# Show HN: A simple hand drawn HTML/CSS theme | 3 188
# Show HN: Create Chrome Extensions for internal use | 3 47
# Show HN: BlockNote – open-source Notion-style Text Editor with Multiplayer | 14 5
# Show HN: 10,000+ places to work from near you | 4 14
# Show HN: Forgo.js – a 4kb React alternative based on plain JS and DOM APIs | 7 110
# Show HN: Plottio – World's stories. Written and read by you | 4 17
# Show HN: SaaS for making software documentation less annoying | 4 25
# Show HN: Dynamic Cards Against Humanity cards based on Facebook data | 3 52
# Show HN: Top PDFs Posted to Hacker News in 2018 | 6 411
# Show HN: type to me, old-school unix talk for the web | 5 43
# Show HN: NextJS + Node.js library for location tracking of business assets | 2 33
# Show HN: OneHumanRace – Trade your time for charity | 4 16
# Show HN: GA Insights – Never Log into Google Analytics Again | 3 42
# Show HN: Looria – A product (re)search engine | 5 15
# Show HN: Corrode – A batteries-included js-library for reading binary data | 4 34
# Show HN: Pagesnap – Take monthly screenshots of any webpage automatically | 4 62
# Show HN: A simple interactive resume-making tool | 4 59
# Show HN: JournalJerk – In 2017, keep a journal—or else | 3 43
# Show HN: Lockless Ringbuffer Built with Go Generics | 6 44
# Show HN: SVG Triangulation for WebGL | 5 94
# Show HN: JsonTree, a 3.53kb JavaScript tool for generating html trees from JSON | 4 78
# Show HN: Introducing KA Lite, an offline version of Khan Academy | 4 61
# Show HN: Gongular - A fast Go web framework with input mapping/validation | 7 11
# Show HN: HSTR – easily view, navigate, search and manage your shell history | 3 33
# Show HN: PlateJoy (YC S15) – Algorithmic meal planner with integrated delivery | 5 65
# Show HN: FI Calc – A Financial Independence Calculator | 4 14
# Show HN: I grouped HN by topics, so you don‘t have to | 4 11
# Show HN: Textnet.io – The Internet of Text | 5 14
# Show HN: My seven minute workout timer evening project | 4 760
# Show HN: Free, open-source site for finding beautiful hikes | 9 145
# Show HN: Our new online face recognition demo | 4 50
# Show HN: Freeciv WebGL 3D | 5 105
# Show HN: Convenient web rss-reader | 5 39
# Show HN: Open-source APM with support for tracing, metrics, and logs | 6 112
# Show HN: We made T Combinator, in case YC reject us today | 5 12
# Show HN: Neural networks tutorial series with code | 5 107
# Show HN: Pagerbot, a chat bot for managing PagerDuty on-call schedules | 3 67
# Show HN: t2md – back up Trello to markdown folders on disk, fast | 6 16
# Show HN: Mousedroid – Use your Android phone as a mouse and keyboard | 3 22
# Show HN: Luna is a Clojure domain specific language that translates to regex | 6 56
# Show HN: CoRM – Lightweight Contact Relationship Management with API Access | 3 18
# Show HN: Booky.io – Online bookmark manager | 4 39
# Show HN: Python Library for Chain.com Bitcoin API | 4 12
# Show HN: Gridfolio – Lightweight and simple portfolio generator | 3 68
# Show HN: Jupyter kernel using Poetry for reproducible Python package management | 3 95
# Show HN: Optery – See the private info data brokers are posting about you online | 4 111
# Show HN: A game I wrote in a day | 5 20
# Show HN: Our video series teaches anyone how to build & deploy a web app | 4 23
# Show HN: Thotly - An Anonymized Layer On Your Local Reality | 3 30
# Show HN: An opinionated approach to have type safety in native JavaScript | 4 19
# Show HN: Building biggest online toolbox on web (57 plus tools with a fancy UI) | 6 38
# Show HN: Redis Dashboard | 4 194
# Show HN: Spotifyd – A spotify daemon | 4 53
# Show HN: I made an iPhone app that helps you manage your S3 files | 3 24
# Show HN: “Do Things That Don't Scale” – A Curated List Inspired by an HN Thread | 5 11
# Show HN: Think Like a Bot – Guess labels applied by AI to random images | 3 34
# Show HN: WrapAPI Proxy, a Zero-Install Charles Proxy Alternative | 7 11
# Show HN: Egyptian Ratscrew Online | 4 41
# Show HN: An extension to turn your LinkedIn into a resume | 4 185
# Show HN: Become a better investor by playing a game with short lessons | 3 17
# Show HN: CloudBuddy – Pay less for online storage | 4 11
# Show HN: A site that makes Spotify playlists of bands coming to town | 4 346
# Show HN: BeerBase – an accessible worldwide open beer database | 6 90
# Show HN: A Machine Learning Model for Salary Estimation | 5 83
# Show HN: InKino – An open-source movie app made with Flutter | 8 148
# Show HN: A collaborative pixel drawing game for when you're bored (Attempt #2) | 5 62
# Show HN: Startup Threads Monthly - Subscription Swag Service | 4 82
# Show HN: Oag – Idiomatic OpenAPI Go client code generator | 4 11
# Show HN: Leafsnap - An electronic field guide with automatic identification | 3 11
# Show HN: An Android Facebook client using only Internet access as permission | 3 12
# Show HN: Find journalists, bloggers and webmasters covering your niche | 4 92
# Show HN: Hetchr, a Developer's Homepage | 4 57
# Show HN: Whitestorm.js – Framework for Three.js Make your 3D game in a few steps | 4 21
# Show HN: Free Online Course – Debugging Difficult Conversations | 4 19
# Show HN: Tipe (YC W18) – Generate an API-First CMS from a GraphQL Schema | 6 17
# Show HN: Gez.la v2 – open-source Virtual Tour Database | 10 3
# Show HN: Staticland – Open source static site hosting with SSL via Let's Encrypt | 8 180
# Show HN: Aim and Shoot – A game where your opponents are neural networks | 5 11
# Show HN: SIEV, a fuzzy reverse image search API | 4 16
# Show HN: Sublime Text plugin to toggle font to Comic Sans | 4 11
# Show HN: Dayboard – Daily task management for teams | 3 36
# Show HN: Get notified when new trading pairs are added to GDAX | 3 12
# Show HN: Displaying Lifespan Info in a D3 Family Tree Visualization | 4 15
# Show HN: Alter – convert text/code to an image | 4 76
# Show HN: Six Degrees of Venmo – Visualizing your payment network | 4 28
# Show HN: Add what Twitter's missing - good thread editor, edit tweets and more | 3 48
# Show HN: MAWD – Simple web accessibility testing for developers | 4 29
# Show HN: InsightFlow | 4 20
# Show HN: OSX-ISO – Create a bootable ISO of macOS from the installation app file | 4 135
# Show HN: JSON as Fast as Binary | 5 12
# Show HN: minicron – a system to manage and monitor cron jobs | 4 31
# Show HN: Everyday.app – a simple and beautiful habit tracker | 3 19
# Show HN: Inflation-adjusted stock charts – Total Real Returns | 4 507
# Show HN: Build AI DAGs with Memory; Run and Validate LLM Tools in Containers | 4 48
# Show HN: Rust-Like Traits in Python | 4 50
# Show HN: Smort.io – Edit, annotate and share articles easily | 4 86
# Show HN: Chirr App  splits text into tweets and posts it as a thread | 3 36
# Show HN: PyBites – sharing our passion for Python, one bite a day | 5 23
# Show HN: List of serverless failure stories | 4 75
# Show HN: An Ephemeral Microblogging App | 4 18
# Show HN: Centric, a Programmable Automation Server | 5 34
# Show HN: SQLMesh – The Future of DataOps | 3 29
# Show HN: Codeium: Free Copilot Alternative for Vim / Neovim | 8 94
# Show HN: A blockchain alternative to Airbnb | 7 67
# Show HN: ShowList – Share Bands You've Seen Live, Discover New Bands | 4 53
# Show HN: Memory AI – Fully Automatic Time Tracking Powered by Deep Learning | 5 14
# Show HN: Acquiredby – Definitive list of tech acquisitions | 3 21
# Show HN: SQRL – Anti-spam rules language Twitter acquired in 2018, open-sourced | 4 200
# Show HN: Online chessboard without any rules | 4 16
# Show HN: TeXMe – Create self-rendering Markdown + LaTeX documents | 6 75
# Show HN: Self-Published Book – “A Pocket Guide to CCPA” for Web Developers | 6 15
# Show HN: VSUAL, a museum-grade art print marketplace | 4 11
# Show HN: When a non-techie wants to look like a hacker | 6 11
# Show HN: All-new Codenvy – on-demand developer workspaces | 4 16
# Show HN: Unbabel API – Human Corrected Machine Translation | 4 143
# Show HN: Data Science Topic List and Textbook Reviews | 4 11
# Show HN: Aperture – Unified Reliability Management for Microservices | 3 45
# Show HN: v8-riscv — Port of JavaScript V8 engine to RISC-V | 5 123
# Show HN: Microsoft Designer – From Idea to Designs in Minutes, Using AI | 4 39
# Show HN: Dog API | 4 275
# Show HN: Automatic Domain Verification | 4 27
# Show HN: Free Writing – Never stare at a blank screen again | 5 18
# Show HN: oso – Open-Source Policy Engine for Authorization | 10 44
# Show HN: Texturner – Human Translation Bot for Slack | 3 13
# Show HN: TagOverflow, a graph map of Stack Overflow topics | 4 32
# Show HN: I built a simple web app for streaming videos | 5 127
# Show HN: Little Warden, monitoring the tedious things about websites | 4 109
# Show HN: A desktop game about money questions | 4 13
# Show HN: Android Weekly - free Android development newsletter | 2 13
# Show HN: Just hit $15k/m running unlimited design service by myself | 4 64
# Show HN: Micro – A platform for cloud native development in Go | 4 44
# Show HN: WildDuck – Self-hosted modern email server | 8 222
# Show HN: FundingHunt – Daily Updates on Startup Funding | 3 24
# Show HN: Frodo – Rails like app generator for Node.js/Express | 3 13
# Show HN: Deep Learning Using TensorFlow – Tutorials and Source Code | 6 31
# Show HN: Split-Grid Generator | 4 89
# Show HN: Blackjack game engine with CLI output | 4 12
# Show HN: I made a pictionary game with Stable Diffusion | 5 16
# Show HN: Hackershelf. Community curated collection of legally free books | 4 532
# Show HN: Jq-in-the-browser -– jq compatible JSON processor in JavaScript | 4 15
# Show HN: Hacker Feed – An iOS app for reading Hacker News | 5 55
# Show HN: Impressi | a WYSIWYG editor for impress.js | 5 17
# Show HN: Sia, a User-Owned Amazon S3 Challenger | 4 21
# Show HN: Open Source Suite for Binary Analysis, Based on QEmu and LLVM | 4 46
# Show HN: File-by-file AI-generated comments for your codebase | 4 51
# Show HN: Simplest and cleanest RSS Search Engine in the world | 5 11
# Show HN: Arturo.io – Automatic book builds on GitHub | 6 13
# Show HN: My First OSS Project, Classic Finder | 4 22
# Show HN: Marketing software for solopreneurs who don't like marketing | 3 74
# Show HN: TLDRs of 300 articles for developers | 5 22
# Show HN: Zenlogin – API to email users when a suspicious login happens | 5 24
# Show HN: Socrates.io - clean and shareable markdown | 5 116
# Show HN: A Movie Trailer Music Website | 5 19
# Show HN: Fast bulk thumbnails image explorer and classification tool for ML | 5 13
# Show HN: Wasmino = WASM and Arduino – Running Arduino Code in Browser | 5 84
# Show HN: Stack Match – Find engineering jobs that match your preferred stack | 4 136
# Show HN: Aristotl – an intuitive logical fallacy lookup tool | 4 173
# Show HN: Sleeping Beauty, a 7-day roguelike game | 4 319
# Show HN: Share what you make (the 2-day app I launched at an HN meetup) | 4 19
# Show HN: A Clojure implementation of logic programming language in SICP | 8 56
# Show HN: Mailer – our in-house tool for sending email from the command line | 4 21
# Show HN: Integrated development window manager | 4 61
# Show HN: Tmuxomatic – An intuitive and flexible session manager for tmux | 4 37
# Show HN: Stein – Use Google Sheets as a No-Setup Database | 5 296
# Show HN: The 8 hour diet web app | 4 52
# Show HN: Moderator Mayhem, a game about the difficulties of content moderation | 3 221
# Show HN: Mljar Automated Machine Learning for Tabular Data (Explanation,AutoDoc) | 5 33
# Show HN: Makejinja: Automatically generate complex Home Assistant configurations | 4 14
# Show HN: Actix web 0.4 – simple and extremely fast web framework for Rust | 8 35
# Show HN: Learn Java and More Online (My 1st real Rails app) | 3 15
# Show HN: Review my project: Git Code Press, blogging via git | 5 31
# Show HN: Lasergist.com – Your custom design in pure, laser-cut Stainless Steel | 4 211
# Show HN: Peer to Peer Recruiting? | 4 49
# Show HN: A Cryptocurrencies logo guessing game built with Vue.js | 6 12
# Show HN: Get started modding Factorio in TypeScript | 3 69
# Show HN: I made a free, open-source playground for AI image models | 10 1
# Show HN: Pinchable image viewer using HTML5, CSS3 & JS | 5 27
# Show HN: Hasura: High performance GraphQL on Postgres | 6 24
# Show HN: Isometric Painting Tool | 4 43
# Show HN: Node.js REPL with GPT3 Completion | 4 15
# Show HN: Groupdate | 4 34
# Show HN: I solved my New Tab page | 3 332
# Show HN: Send your items worldwide with travelers or make money while traveling | 4 19
# Show HN: “Who's Hiring” Trends | 4 11
# Show HN: Orchest – Data Science Pipelines | 4 64
# Show HN: RegEx Face Off – Beat your friends with regular expressions | 4 70
# Show HN: Cpi – Immediately compile and execute c++ program like a scripting lang | 5 65
# Show HN: a Node.js personal cloud you can hack, host and delete | 3 65
# Show HN: Trivial script to spin up a Debian MIPS|PPC|arm|x86|x64 VM | 3 34
# Show HN: We made this to help people stop getting tracked (Data Privacy Day) | 5 49
# Show HN: Emacs-Bootstrap | 4 26
# Show HN: Knock – Notification Infrastructure for Developers | 4 17
# Show HN: Shared – Triptych for data exchange and persistence | 3 14
# Show HN: Weird JSON superset with BigInt, Infinity, TypedArray etc | 4 67
# Show HN: Todos: Backbone.js example + Google App Engine (Python) | 5 38
# Show HN: Sunflower Editor – like adding console.log to every line of your code | 6 134
# Show HN: Screenr – Automated Workflow for Your Email | 4 118
# Show HN: Pesto, a Digital Workplace | 3 86
# Show HN: I built a better UI for ChatGPT | 6 183
# Show HN: DubJS: A New Way to Build Web Apps | 6 57
# Show HN: MPL Plotter – Python library to make technical plots more efficiently | 5 48
# Show HN: A chat client built on git | 6 81
# Show HN: No more “idea websites” – here's a problem solving website | 5 52
# Show HN: Hound – Elixir web driver library for integration tests | 4 38
# Show HN: Simple PDF to PNG Server | 5 78
# Show HN: Advenjure – Interactive fiction on the terminal and in the browser | 7 80
# Show HN: local independent band discovery service | 3 14
# Show HN: Campus FM – live stream college and independent radio stations | 3 212
# Show HN: Walling comes to Windows to help you organize your ideas | 4 14
# Show HN: Store.js v2.0 – Cross-browser storage for all use cases | 4 162
# Show HN: Scrapy Middleware for Named Entity Recognition with Stanford CoreNLP | 4 12
# Show HN: Kubist, a little web app to make cubism-like images | 4 231
# Show HN: Babeloop, a new music sight-reading webapp | 4 12
# Show HN: It's Popcorn Time - Stream movies using node-webkit and backbone | 4 78
# Show HN: Video conference from 6ft away using your hands or phone to interact | 3 126
# Show HN: I made Hacker News 4chan-style | 7 40
# Show HN: We've built graphics comparison tool | 5 23
# Show HN: Stretch – A high-performance cross-platform layout engine in Rust | 6 213
# Show HN: A list of short .com domains that are available | 4 13
# Show HN: A portfolio website simulating Ubuntu 20.04 | 4 19
# Show HN: An Actually-Tiny Basic for Arduino | 3 24
# Show HN: I built a community for women entrepreneurs and makers | 4 345
# Show HN: A no-nonsense Jekyll theme for sensible blogging | 4 57
# Show HN: Taps.io is bit.ly for apps | 5 27
# Show HN: Vestidd - An online organizer for loved ones with special needs | 3 14
# Show HN: CanvasMol molecule viewer (JS + canvas demo) | 4 72
# Show HN: Free 3D icons, fully customizable online | 5 56
# Show HN: Reply to Hacker News comments inline, without leaving the page | 6 24
# Show HN: I send out a weekly CS topic overview and code interview question | 3 117
# Show HN: My first Android app - Hacker News reader | 4 40
# Show HN: Il2cpp-modder – Generate DLL injection projects for hacking Unity games | 4 69
# Show HN: PSX Party – Online Multiplayer Playstation 1 Emulator Using WebRTC | 6 676
# Show HN: Vinyl record and sleeve grading tool | 4 63
# Show HN: I love Essential Mixes. So I made this.  | 5 125
# Show HN: Atri: an experiment in web economics | 4 65
# Show HN: Fast Real-Time Anomaly Detection in Dynamic Graphs | 7 118
# Show HN: I built a spreadsheet app with Python to make data science easier | 7 84
# Show HN: My side project about side projects | 6 66
# Show HN: Ghuser.io – Complete GitHub profiles | 4 157
# Show HN: Framer Studio – Interaction Design Tool | 4 29
# Show HN: Pay-per-minute video/audio calls with WebRTC | 5 47
# Show HN: Sonification of Income Inequality on the NYC Subway | 4 15
# Show HN: Bloben – Self-hosted web CalDAV calendar client | 6 50
# Show HN: Proxino - optimize and monitor your javascript | 4 87
# Show HN: A real-time Twitter clone in 300 lines of Angular.js | 4 12
# Show HN: API Spec Converter – Convert between different API definition formats | 4 12
# Show HN: Livestream 90sec moments and see friends facial expressions in realtime | 4 13
# Show HN: Hooks Data API – Realtime Data about Thousands of Topics Over Webhooks | 6 145
# Show HN: Polly Podcast – Listen to blog posts at work | 3 14
# Show HN: Help job seekers by letting them ask employees anonymous questions | 4 55
# Show HN: A raytracer to shade topographic maps in R, Part 2 | 4 76
# Show HN: My weekend project, QR-codes for everybody | 5 203
# Show HN: A Werewolf bot for Slack | 3 96
# Show HN: Coffee Chat – Trade your expertise | 4 182
# Show HN: My plea for hackers in medicine | 6 15
# Show HN: I built a site to find the best newsletters | 5 12
# Show HN: Tribalpedia – Free Learning About Native American Indians | 5 55
# Show HN: Common ownership between S&P 500 companies | 5 45
# Show HN: An Interpreter for Extended Relational Algebra (Scheme Based) | 4 52
# Show HN: Kickflip – Open Source Live Mobile Video Streaming SDKs | 4 39
# Show HN: Beating Hinton et al.'s capsule net with fewer params and less training | 3 14
# Show HN: Linux tool to show progress for cp, rm, dd, etc. | 2 252
# Show HN: My first personal app - HackerNews for iPhone/iPad | 4 107
# Show HN: Generate realistic handwriting with neural networks [demo] | 5 66
# Show HN: Open-Source Alternative to Hubspot and Intercom | 12 6
# Show HN: Toola – the open-source Retool alternative | 13 7
# Show HN: Stringer, a self-hosted anti-social RSS reader | 6 22
# Show HN: WrapAPI v2 – build APIs on top of existing sites | 5 13
# Show HN: Google Music for Mac | 4 193
# Show HN: No More Google, privacy-friendly alternatives to Google products | 6 96
# Show HN: Dyna-Kinematics – A 2D physics simulator with some unique features | 4 78
# Show HN: Invertris (made by a friend of mine) | 5 41
# Show HN: A Scala Implementation of the Chromaprint/AcoustID Audio Fingerprinter | 4 49
# Show HN: Great Books Homeschool beta program | 4 45
# Show HN: Strukt – a visual shell for tabular data | 6 191
# Show HN: My weekend project: Twtspire | 5 73
# Show HN: Gridentio – A small puzzle I made to learn some react and node | 5 11
# Show HN: Defguard – open-source security army knife (Identity,MFA,VPN,Yubikey) | 8 32
# Show HN: My first Kickstarter – Home automation for products you already own | 4 12
# Show HN: 40k HN comments mentioning books, extracted using deep learning | 8 1359
# Show HN: Reactuate – a React/Redux stack with a focus on domain-driven design | 4 49
# Show HN: Add 3D gestures to your applications | 4 28
# Show HN: I'm releasing my game for free | 5 195
# Show HN: Endpoints.dev – Pastebin for HTTP Requests | 4 201
# Show HN: Tempmail.de – Temporary, disposable, anonymous email address | 5 66
# Show HN: Registered Domain Names Search | 4 22
# Show HN: Yet Another Open Map | 4 27
# Show HN: Unwonted.io – in-browser, offline tool for generative art, mainly NFTs | 4 17
# Show HN: This up votes itself | 4 3531
# Show HN: Distilhn.com – Front-Page Articles Summarized with Machine Learning | 5 34
# Show HN: SQL Habit – learn SQL with Real Examples from Product and Marketing | 6 51
# Show HN: Sysdig Inspect – opensource interface for container forensics | 7 13
# Show HN: A simple lightweight CSS grid, not a bloated framework | 6 134
# Show HN: Cujo's Curated SIDs | 4 39
# ...
# Show HN: What to use instead of WhatsApp | 4 13
# Show HN: We created a password and data manager for teams | 5 21
# Show HN: Cr – Runs your tasks at maximum concurrency | 4 83
# Show HN: Copilot for Data Analysis, beyond an open-source alternative to Tableau | 12 61
# Show HN: Speleomorph, an Exploration Puzzle | 4 11
# Show HN: InstaNote – notes in a simple chat interface | 4 89
# Show HN: The World's Fastest Workout | 4 16
# Show HN: DuskJS – enable your single page apps for offline use | 5 20
# Show HN: Grain – Share Zoom video clips, transcripts, and live notes for free | 4 12
# Show HN: MindMapIt, a simple webapp to create mind maps | 4 14
# Show HN: Query an RDBMS in JSON (an interactive demo) – Hasura | 5 12
# Show HN: Kur by Deepgram (YC S16) – Deep Learning Made Easy | 8 103
# Show HN: Fast Rolling Quantiles for Python | 5 79
# Show HN: I made a database of remote companies | 7 171
# Show HN: Glose, a next-generation social reading platform for ebooks | 3 24
# Show HN: A Multiplayer Geography Game Using WebSockets | 5 220
# Show HN: Code4Startup - Learn to code by cloning real life startups | 5 113
# Show HN: BetaList Bundle – Get Access to the Best Startup Tools | 4 14
# Show HN: My Technical Blogging book for hackers and founders is now in Beta | 6 80
# Show HN: Mathigon – an interactive, personalised mathematics textbook | 5 22
# Show HN: Discover your ranking on GitHub | 4 137
# Show HN: Trigger Happy, a selfhosted clone of IFTTT | 6 26
# Show HN: Stairway takes meetings to iPhone | 3 20
# Show HN: Fern, a language for defining REST APIs that compiles into OpenAPI | 5 18
# Show HN: Fff – A terminal file manager written in bash | 6 55
# Show HN: Ironclad – an automated legal assistant | 4 105
# Show HN: Surfboard – CodeSandbox for Arduino | 4 26
# Show HN: Pisa – Performant Indexes and Search for Academia | 4 17
# Show HN: Frogtop.us – A personal, private, distributed pastebin | 6 11
# Show HN: Placemat, pretty nice placeholder images | 4 12
# Show HN: Stackby – Spreadsheets, Databases and No-code APIs in a single platform | 7 92
# Show HN: Foxr – Puppeteer-Like Selenium-Free Node.js API to Control Firefox | 4 15
# Show HN: Deploy ML Models on a Budget | 4 117
# Show HN: Highbrow – Bite-sized email courses delivered to your inbox daily | 4 78
# Ask HN: Why are there so few Show HN threads on homepage these days? | 4 14
# Show HN: Materialistic – Hacker News Android client with material design | 4 11
# Show HN: I built a tiny platform where you can say anything you want | 6 20
# Show HN: Terragen.dev – Automagically Generate Terraform for AWS | 4 73
# Show HN: Run your own OAuth2 and OpenID Connect Provider | 4 88
# Show HN: JackDB — Database development in your web browser | 7 12
# Show HN: Trophi.com – A forum the represents both sides of an argument | 4 48
# Show HN Parents: StarChart.me — Online star chart for kids | 4 32
# Show HN: travel.meteor.com: clone of mywanderlust in Meteor  | 4 18
# Show HN: Whaller – create private social networks for your org and community | 3 41
# Show HN: Work Hard Anywhere – The best laptop-friendly cafes and workspaces | 4 11
# Show HN: DeepRadio lets you search and clip radio snippets | 4 13
# Show HN: Robotic pour-over coffee | 4 16
# Show HN: Bookmory – easy and powerful reading tracker | 3 12
# Show HN: 7courses, the recipe manager.  | 5 23
# Show HN: my spare time project, an on-site QR image decoder | 4 14
# Show HN: Formpost.co – Send forms from your static site | 5 19
# Show HN: BreakLock – A hybrid of Mastermind and the Android pattern lock | 3 139
# Show HN: Antimander – Optimize Congressional Districts with Genetic Algorithms | 4 68
# Show HN: Now.me – Get to the meeting you're supposed to be in | 4 17
# Show HN: NoAgeismInTech Job Board (Update) – Companies' Culture | 3 39
# Show HN: my first startup, MusicRage: pay-as-you-like bundle of music | 4 16
# Show HN: A Lispy Calculator in under 50 Lines of OCaml | 4 15
# Show HN: A mobile-friendly, web-based, countries of the world game | 4 112
# Show HN: Ceramic – Create, host, and share decentralized data streams | 4 18
# Show HN: Privaxy – Like uBlock but through a MitM proxy and no browser extension | 5 14
# Show HN: Dopamine API – Turn any app into a habit | 5 31
# Show HN: A little eye-candy for the terminal (in Go) | 6 56
# Show HN: Notepin – Extremely simple blogging platform | 4 144
# Show HN: faasd – Lightweight Serverless for Your Raspberry Pi Without Kubernetes | 6 17
# Show HN: The First web site ever programmed in ActionScript 3.0 | 5 11
# Show HN: GoGITiT - GitHub Usage Statistics of JS Frameworks | 4 13
# Show HN: All desktop software calculators are wrong, so I had to build my own | 5 286
# Show HN: Easiest UTM Tags Builder | 3 17
# Show HN: We made a spam-free lyric search engine | 6 291
# Show HN: Commandcar – a CLI tool that can easily communicate with any API | 3 82
# Show HN: Interactive Rubik's Cube with sub-puzzles for solution steps | 4 51
# Show HN: Unioncy – Keep an automated record of your things | 4 36
# Show HN: Partially encrypt a file based on its HEREDOCs | 4 38
# Show HN: Tiny, fast, and free API to geolocate IP addresses | 7 144
# Show HN: Moqups - Vectorial mockups with HTML5 and SVG | 5 310
# Show HN: YC's startup advice, organized and searchable | 4 161
# Show HN: NanaGram – SMS photos and we'll mail 4x6 prints to your Grandma | 5 14
# Show HN: Hacker News reader for Android tablets | 5 24
# Show HN: I'm building a github for guitarists and bass players | 7 17
# Show HN: EasyFridge – Subscription Grocery Delivery. No Thinking Required. | 4 11
# Show HN: No More Open Tabs Left at the Bar | 4 13
# Show HN: IPalyzer – Analyze any IP for location, RDNS, blacklisting | 4 123
# Show HN: A an R7RS Scheme Implementation in WebAssembly | 4 84
# Show HN: BlockTube - YouTube content blocker | 3 17
# Show HN: Strange Binary – a cellular automata game | 4 13
# Show HN: Pen.el (Working GPT-3/LM for Emacs with easy Docker install) | 4 15
# Show HN: GPT Joke Writer | 4 51
# Show HN: I am trying to start a webring for geeks | 3 235
# Show HN: I made a website for you to travel the world in first-person POV | 5 390
# Show HN: Parallax wallpaper engine for Linux and Windows | 6 225
# Show HN: AST-grep, a grep/eslint/codemod hybrid tool, powered by tree-sitter. | 4 11
# Show HN: Apify – Turn any website into an API | 6 45
# Show HN: MOS, an application to help you deploy mathematical optimization models | 4 12
# Show HN: SSH Permit A38 – Central Managment and Deployment for SSH Keys | 6 86
# Show HN: Synth.fm | 4 17
# Show HN: See which friends work close by in SF | 4 16
# Show HN: Linbox – a free, open-source Google Inbox alternative | 12 8
# Show HN: Mockingjay – Fake servers and consumer-driven contracts | 5 39
# Show HN: Manage your gif collection, search and drag/drop from a desktop app | 3 29
# Show HN: I've built a C# IDE, Runtime, and AppStore inside Excel | 8 670
# Show HN: JWEB (a modern implementation of the CWEB Literate Programming system) | 6 40
# Show HN: Mind, a flexible neural network in JavaScript | 6 20
# Show HN: FounderPhone – make customer support personal with SMS | 4 106
# Show HN: Programming with Escher | 5 110
# Show HN: How we used Gatsby and Puppeteer to create dynamic Open Graph images | 5 13
# Show HN: RudderStack, open-source CDI (a.k.a. open-source Segment) | 13 123
# Show HN: UrlRoulette – Pass a URL to the next visitor | 3 36
# Show HN: StringBean – 4K Featherweight Framework | 5 28
# Show HN: Koda, a typesafe functional toolkit for Python | 5 110
# Show HN: I wrote an eBook on tracking personal finances using Python | 6 30
# Show HN: My humble little side project to support OSS and developer happiness | 5 16
# Show HN: MyIcons – a flat icon manager and font builder for team | 5 15
# Show HN: A web-based pool (billiards) simulator to improve your real-life game | 5 35
# Show HN: SMS Interface for Stable Diffusion | 4 50
# Show HN: Swift vs. Objective-C Benchmarks | 3 12
# Show HN: piCards- Computer vision based audience polling solution for classrooms | 3 52
# Show HN: I made a site that lets you generate AI images using templates | 5 11
# Show HN: WAPM – WebAssembly Package Manager | 4 186
# Show HN: Interactive SICP | 5 280
# Show HN: Netflix Showdown – because I can't decide what to watch | 4 37
# Show HN: BigPipe is a radical new modular web pattern for Node.js | 4 12
# Show HN: Design System Playground | 4 85
# Show HN: Instantly pass your passwords securely | 4 31
# Show HN: Single Makefile static page generator | 4 12
# Show HN: No/Low code in-app onboarding guides for SaaS businesses | 4 55
# Show HN: Cloud Maker – Rapidly create cloud architecture diagrams | 4 123
# Show HN: Replace 't' with 'q' in a Spotify URL to remove personalization | 4 12
# Show HN: Griddle 1.0 – A customizable datagrid component for React | 4 60
# Show HN: Earn 9.62% on US Treasury I Bonds on Yotta | 4 83
# Show HN: A pure Swift port of the Cassowary linear constraints solver | 3 39
# Show HN: Visualizing real-time tweets and Wikipedia updates | 4 14
# Show HN: Haystack – Visibility into How Software Teams Works | 4 39
# Show HN: Set OS X files and folders to self-destruct based on tag | 3 32
# Show HN: pure client-side Connect Four AI with Web Workers, AngularJS, Firebase | 4 39
# Show HN: Iconizer – Effortlessly resize iOS icons | 3 16
# Show HN: Box2D fluid simulation in WebGL and WASM | 6 71
# Show HN: Assembly to C code Decompiler | 4 98
# Show HN: Email hasn't changed in 20 years, I've coded something new for 9 months | 7 50
# Show HN: Analytics / CRM hybrid | 4 45
# Show HN: Open Paperless – Scan, index, and archive paper documents | 5 285
# Show HN: Deaf? My iPhone app wakes you up if it hears an alarm | 3 170
# Show HN: HN Detox – Hacker News Daily Newsletter | 5 14
# Show HN: Kenvak, representation for freelance web professionals | 4 26
# Show HN: Thyme, a simple CLI to measure human time and focus | 3 99
# Show HN: Subreddit Finder – find subreddits based on a topic | 4 83
# Show HN: Replin – A cross-platform P2P selling profile built on Ethereum | 6 11
# Show HN: Bitcoin M-of-N Multisig P2SH Transaction Builder in Go | 4 40
# Show HN: React-Express-stripe – Accept Payments from Users with This Boilerplate | 4 14
# Show HN: Publisheet – Publish Excel sheets as interactive web pages | 6 188
# Show HN: Android App: Twitter Version of Quora/AskReddit/Yahoo Answers | 2 17
# Show HN: Lsvine: `tree -L 2` with less empty screen space | 4 31
# Show HN: 288 Analog Clocks Give Digital Time | 3 117
# Show HN: Prophecy Spark IDE public beta | 3 12
# Show HN: CMS Server written in Go (alpha) | 6 61
# Show HN: Badger-Rails | 4 28
# Show HN: Tokumei – Anonymous microblogging | 4 20
# Show HN: Get clean readable content from any webpage | 3 80
# Show HN: Zuplo – Programmable, Serverless API Management for Developers | 5 17
# Show HN: 1024, a 2048 Puzzle Game | 3 101
# Show HN: WriteFreely – minimalist, federated blogging platform | 5 337
# Show HN: Stintin - jobs for the not so faint of heart | 4 11
# Show HN: Swell – Impact Investing Platform | 4 16
# Show HN: Canvas Glue, get the most out of reading and researching on the web. | 4 24
# Show HN: Wia – Rock Solid Cloud Infrastructure for IoT | 4 12
# Show HN: EnvKey 2.0 – End-To-End Encrypted Environments (now open source) | 7 225
# Show HN: Qikipedia - Wikipedia's summary cards on any web page | 4 11
# Show HN: Our attempt at fixing Google Contacts | 4 28
# Show HN: Harmogram, Web Audio API + Canvas (Paper.js) FFT/Harmonograph | 5 105
# Show HN: Kyso – Publish Your Jupyter Notebooks as Blog Posts | 4 22
# Show HN: A programming language that uses only parentheses | 6 55
# Show HN: Simple way to obtain pseudorandomness from CPU context switch in Go | 4 34
# Show HN: Bot that mentions potential reviewers on pull requests | 3 72
# Show HN: SeKey: An SSH Agent for OS X, Using Secure Enclave and TouchID, in Rust | 5 169
# Show HN: Edworking – All-in-one productivity platform for teams | 4 63
# Show HN: jsdares – learning programming visually | 7 177
# Show HN: Apple – Every Second | 4 172
# Show HN: idle.fm - Spotify playlists based on your Facebook profile | 3 13
# Show HN: DataFart - easy command line graphing | 3 114
# Show HN: A book introducing Geospatial and Rust | 6 11
# Show HN: HN Pop-Up – Hover on HN Username to See Their Profile | 5 17
# Show HN: Hapibelly, Rotten Tomatoes for Restaurants | 4 40
# Show HN: Caman – A self-signing certificate authority manager | 4 26
# Show HN: Jarvis AI – your dedicated concierge for anything | 4 12
# Show HN: Clipboard Plus, free and open-source clipboard manager for Windows | 7 59
# Show HN: Ear training using midi.js | 4 230
# Show HN: Heap is a new approach to analytics. Just capture everything | 4 339
# Show HN: Is it vulnerable? Drag-n-drop your Gemfile.lock to check | 3 175
# Show HN: Etherlearn – Visual Blockchain Simulator | 5 23
# Show HN: Interfacer – suggest interface types in Go | 4 66
# Show HN: Get Creative, a website within a chrome extension | 3 37
# Show HN: Easily consume REST APIs with Go | 4 51
# Show HN: Secure Linux Apps on the Mac Desktop Through Docker | 7 21
# Show HN: Minimum Viable Technology (MVT) – Move Fast and Keep Shipping | 5 30
# Show HN: Galène Videoconferencing Server | 4 132
# Show HN: A self-hosted js compiler in 1k loc | 6 47
# Show HN: My first Android App – order-taker for family company that sells wood | 3 123
# Show HN: Firefox addon which shows tabs grouped by containers in the sidebar | 1 16
# Show HN: Twingate – A modern solution for remote access | 4 156
# Show HN: YAMQ – Yet Another (delayed) Message Queue | 3 14
# Show HN: Hacker News for cryptocurrency and Blockchain | 5 77
# Show HN: Hacker News Discourse turns HN stories into Clubhouse-style audio rooms | 7 36
# Show HN: Bionic Reading – Formats text to make it faster to read | 6 410
# Show HN: Create beautiful videos from screenshots or pdf in seconds | 4 21
# Show HN: Empirical – a language for time-series analysis | 4 111
# Show HN: Free Math, an offline React app for managing digital math homework | 3 138
# Show HN: Hiding code from Git diff | 5 167
# Show HN: Svelvet – A component library for building interactive flow diagrams | 7 354
# Show HN: 1Poshword, cross-platform PowerShell client for 1Password | 4 66
# Show HN: Parapet – A purely functional library to build distributed systems | 6 51
# Show HN: A Python toolkit for processing tabular data | 6 17
# Show HN: shelf-reading & inventory management with augmented reality | 3 90
# Show HN: Sandbox – instantly mock REST and SOAP web services | 4 12
# Show HN: PagerNation – A simple, free, and secure browser-based intercom | 4 69
# Show HN: Rate All The Things | 4 18
# Show HN: WriterKata – a site for writers to practice their craft | 4 93
# Show HN: Chat for Trello | 4 75
# Show HN: A database of everything (over 55M keys) | 6 97
# Show HN: An iMessage Scheme REPL. scheme [at] irepl.im | 4 23
# Show HN: Nsynjs – JS engine with stoppable threads and without callback hell | 5 51
# Show HN: Pmfx-shader – Cross platform shader system | 4 57
# Show HN: Zoom meetings are a time suck – async video updates are the new jam | 2 33
# Show HN: Rack Elevation Diagram Generator in JavaScript | 5 31
# Show HN: A distributed Recommendation Engine based on Redis + Ruby (and C)  | 5 97
# Show HN: Stellar Jackpot | 4 56
# Show HN: Point your repos to their new home | 4 23
# Show HN: Reddit-based product recommendations (weekend project) | 4 66
# Show HN: Git (& Jekyll) backed websites anyone can edit. Beta | 3 61
# Show HN: A Repository of Recruiter Email Domains and Email Filter Automation | 5 11
# Show HN: Txxt.app – an ultra simple SMS notepad | 4 20
# Show HN: Tokei 12 – A fast and accurate code analysis tool | 5 19
# Show HN: Peek into a remote repo from GitHub or Gitlab quickly | 4 32
# Show HN: the iPhone version of News/YC, a Hacker News reader | 5 110
# Show HN: Share and Discover Side Projects | 4 52
# Show HN: ReallyConfused – Explore, create and share self-learning tech roadmaps | 3 14
# Show HN: Gmelius 6 – Gmail just got better | 4 61
# Show HN: Public Datasets for Machine Learning | 4 26
# Show HN: Career Finder – A quiz that gives you career recommendations | 3 43
# Show HN: Conclave, a decentralized, real-time, collaborative text editor | 10 22
# Show HN: A Browser-based Blockchain | 4 186
# Show HN: Next Browser native on Linux | 6 198
